# %% [markdown]
# # EDA and Alignment of many Datasets of text
# ---

# %%
import pandas as pd

# %% [markdown]
# # Take All dante corpus

# %%
def dividi_blocchi(rows):
    blocks_texts= []
    current_block_text= []
    i=0
    for r in rows:
        if r.strip():
            current_block_text.append(r.strip())
        else:
            #print(f"{i}° blocco",current_block_text)
            if current_block_text:
                blocks_texts.append(current_block_text)
                current_block_text= []
    #for last row
    if current_block_text:
         blocks_texts.append(current_block_text)
    return blocks_texts

# %%
#link traduction  dante divina commedia https://divinacommedia.weebly.com/inferno-canto-i.html

with open("Inferno_original_dante.txt", "r", encoding="utf-8") as f:
    rows=f.readlines()
    ancient_block_texts=dividi_blocchi(rows)
print(ancient_block_texts)

with open("Purgatorio_original_dante.txt","r",encoding="utf-8") as f:
    rows=f.readlines()
    ancient_block_texts_purgat=dividi_blocchi(rows)
print(len(ancient_block_texts_purgat))

with open("paraf_purgatorio.txt","r",encoding="utf-8") as f:
    rows=f.readlines()
    modern_block_texts_purgat=dividi_blocchi(rows)
print(len(modern_block_texts_purgat))
# Out:
# [['Nel mezzo del cammin di nostra vita', 'mi ritrovai per una selva oscura,', 'ché la diritta via era smarrita.'], ['Ahi quanto a dir qual era è cosa dura', 'esta selva selvaggia e aspra e forte', 'che nel pensier rinova la paura!'], ['Tant’è amara che poco è più morte;', 'ma per trattar del ben ch’i’ vi trovai,', 'dirò de l’altre cose ch’i’ v’ho scorte.'], ['Io non so ben ridir com’i’ v’intrai,', 'tant’era pien di sonno a quel punto', 'che la verace via abbandonai.'], ['Ma poi ch’i’ fui al piè d’un colle giunto,', 'là dove terminava quella valle', 'che m’avea di paura il cor compunto,'], ['guardai in alto e vidi le sue spalle', 'vestite già de’ raggi del pianeta', 'che mena dritto altrui per ogne calle.'], ['Allor fu la paura un poco queta,', 'che nel lago del cor m’era durata', 'la notte ch’i’ passai con tanta pieta.'], ['E come quei che con lena affannata,', 'uscito fuor del pelago a la riva,', 'si volge a l’acqua perigliosa e guata,'], ['così l’animo mio ch’ancor fuggiva,', 'si volse a retro a rimirar lo passo', 'che non lasciò già mai persona viva.'], ['Poi ch’èi posato un poco il corpo lasso,', 'ripresi via per la piaggia diserta,', 'sì che ’l piè fermo era sempre ’l più basso.'], ['Ed ecco, quasi al cominciar de l’erta,', 'una lonza leggiera e presta molto,', 'che di pel macolato era coverta;'], ['e non mi si partia dinanzi al volto,', 'anzi ’mpediva tanto il mio cammino,', 'ch’i’ fui per ritornar più volte vòlto.'], ['Temp’era dal principio del mattino,', 'e ’l sol montava ’n sù con quelle stelle', 'ch’eran con lui quando l’amor divino'], ['mosse di prima quelle cose belle;', 'sì ch’a bene sperar m’era cagione', 'di quella fiera a la gaetta pelle'], ['l’ora del tempo e la dolce stagione;', 'ma non sì che paura non mi desse', 'la vista che m’apparve d’un leone.'], ['Questi parea che contra me venisse', 'con la test’alta e con rabbiosa fame,', 'sì che parea che l’aere ne tremesse.'], ['Ed una lupa, che di tutte brame', 'sembiava carca ne la sua magrezza,', 'e molte genti fé già viver grame,'], ['questa mi porse tanto di gravezza', 'con la paura ch’uscia di sua vista,', 'ch’io perdei la speranza de l’altezza.'], ['E qual è quei che volentieri acquista,', 'e giugne ’l tempo che perder lo face,', 'che ’n tutti i suoi pensier piange e s’attrista,'], ['tal mi fece la bestia sanza pace,', 'che venendomi ’ncontro a poco a poco', 'mi ripigneva là dove ’l sol tace.'], ['Mentre ch’i’ rovinava in basso loco,', 'dinanzi agli occhi mi si fu offerto', 'chi per lungo silenzio parea fioco.'], ['Quando vidi costui nel gran diserto,', '«Miserere di me,» gridai a lui,', '«qual che tu sii, od ombra od omo certo!»'], ['Rispuosemi: «Non omo, omo già fui,', 'e li parenti miei furon lombardi,', 'mantoani per patria ambedui.'], ['Nacqui sub Iulio, ancor che fosse tardi,', 'e vissi a Roma sotto ’l buono Augusto', 'al tempo de li dei falsi e bugiardi.'], ['Poeta fui, e cantai di quel giusto', 'figliuol d’Anchise che venne di Troia', 'poi che il superbo Ilïón fu combusto.'], ['Ma tu perché ritorni a tanta noia?', 'perché non sali il dilettoso monte', 'ch’è principio e cagion di tutta gioia?»'], ['«Or se’ tu quel Virgilio e quella fonte', 'che spandi di parlar sì largo fiume?»,', 'rispuos’io lui con vergognosa fronte.'], ['«O de li altri poeti onore e lume,', 'vagliami ’l lungo studio e ’l grande amore', 'che m’ha fatto cercar lo tuo volume.'], ['Tu se’ lo mio maestro e ’l mio autore,', 'tu se’ solo colui da cu’ io tolsi', 'lo bello stilo che m’ha fatto onore.'], ['Vedi la bestia per cu’ io mi volsi;', 'aiutami da lei, famoso saggio,', 'ch’ella mi fa tremar le vene e i polsi».'], ['«A te convien tenere altro viaggio,»', 'rispuose, poi che lagrimar mi vide,', '«se vuo’ campar d’esto loco selvaggio;'], ['ché questa bestia, per la qual tu gride,', 'non lascia altrui passar per la sua via,', 'ma tanto lo ’mpedisce che l’uccide;'], ['e ha natura sì malvagia e ria,', 'che mai non empie la bramosa voglia,', 'e dopo ’l pasto ha più fame che pria.'], ['Molti ...
# 41
# 41

# %% [markdown]
# ### Alignment of First chapter of inferno

# %%
#alignment of block of text for translation block-by-block
ancient_block_texts[4]+=ancient_block_texts[5]
ancient_block_texts.remove(ancient_block_texts[5])
ancient_block_texts[7]+=ancient_block_texts[8]
ancient_block_texts[6]+=ancient_block_texts[7]
ancient_block_texts.remove(ancient_block_texts[7])
ancient_block_texts[6]=ancient_block_texts[6][0:6]
ancient_block_texts[8]+=ancient_block_texts[9] 
ancient_block_texts.remove(ancient_block_texts[9])
ancient_block_texts[9]+=ancient_block_texts[10]+ancient_block_texts[11]
ancient_block_texts.remove(ancient_block_texts[10])
ancient_block_texts.remove(ancient_block_texts[10])
ancient_block_texts[11]+=ancient_block_texts[12]
ancient_block_texts.remove(ancient_block_texts[12])
ancient_block_texts[12]+=ancient_block_texts[13]
ancient_block_texts.remove(ancient_block_texts[13])
ancient_block_texts[30]+=ancient_block_texts[31]
ancient_block_texts.remove(ancient_block_texts[31])
ancient_block_texts[35]+=ancient_block_texts[36]
ancient_block_texts.remove(ancient_block_texts[36])
ancient_block_texts
# Out:
# [['Nel mezzo del cammin di nostra vita',
#   'mi ritrovai per una selva oscura,',
#   'ché la diritta via era smarrita.'],
#  ['Ahi quanto a dir qual era è cosa dura',
#   'esta selva selvaggia e aspra e forte',
#   'che nel pensier rinova la paura!'],
#  ['Tant’è amara che poco è più morte;',
#   'ma per trattar del ben ch’i’ vi trovai,',
#   'dirò de l’altre cose ch’i’ v’ho scorte.'],
#  ['Io non so ben ridir com’i’ v’intrai,',
#   'tant’era pien di sonno a quel punto',
#   'che la verace via abbandonai.'],
#  ['Ma poi ch’i’ fui al piè d’un colle giunto,',
#   'là dove terminava quella valle',
#   'che m’avea di paura il cor compunto,',
#   'guardai in alto e vidi le sue spalle',
#   'vestite già de’ raggi del pianeta',
#   'che mena dritto altrui per ogne calle.'],
#  ['Allor fu la paura un poco queta,',
#   'che nel lago del cor m’era durata',
#   'la notte ch’i’ passai con tanta pieta.'],
#  ['E come quei che con lena affannata,',
#   'uscito fuor del pelago a la riva,',
#   'si volge a l’acqua perigliosa e guata,',
#   'così l’animo mio ch’ancor fuggiva,',
#   'si volse a retro a rimirar lo passo',
#   'che non lasciò già mai persona viva.'],
#  ['Poi ch’èi posato un poco il corpo lasso,',
#   'ripresi via per la piaggia diserta,',
#   'sì che ’l piè fermo era sempre ’l più basso.'],
#  ['Ed ecco, quasi al cominciar de l’erta,',
#   'una lonza leggiera e presta molto,',
#   'che di pel macolato era coverta;',
#   'e non mi si partia dinanzi al volto,',
#   'anzi ’mpediva tanto il mio cammino,',
#   'ch’i’ fui per ritornar più volte vòlto.'],
#  ['Temp’era dal principio del mattino,',
#   'e ’l sol montava ’n sù con quelle stelle',
#   'ch’eran con lui quando l’amor divino',
#   'mosse di prima quelle cose belle;',
#   'sì ch’a bene sperar m’era cagione',
#   'di quella fiera a la gaetta pelle',
#   'l’ora del tempo e la dolce stagione;',
#   'ma non sì che paura non mi desse',
#   'la vista che m’apparve d’un leone.'],
#  ['Questi parea che contra me venisse',
#   'con la test’alta e con rabbiosa fame,',
#   'sì che parea che l’aere ne tremesse.'],
#  ['Ed una lupa, che di tutte brame',
#   'sembiava carca ne la sua magrezza,',
#   'e molte genti fé già viver grame,',
#   'questa mi porse tanto di gravezza',
#   'con la paura ch’uscia di sua vista,',
#   'ch’io perdei la speranza de l’altezza.'],
#  ['E qual è quei che volentieri acquista,',
#   'e giugne ’l tempo che perder lo face,',
#   'che ’n tutti i suoi pensier piange e s’attrista,',
#   'tal mi fece la bestia sanza pace,',
#   'che venendomi ’ncontro a poco a poco',
#   'mi ripigneva là dove ’l sol tace.'],
#  ['Mentre ch’i’ rovinava in basso loco,',
#   'dinanzi agli occhi mi si fu offerto',
#   'chi per lungo silenzio parea fioco.'],
#  ['Quando vidi costui nel gran diserto,',
#   '«Miserere di me,» gridai a lui,',
#   '«qual che tu sii, od ombra od omo certo!»'],
#  ['Rispuosemi: «Non omo, omo già fui,',
#   'e li parenti miei furon lombardi,',
#   'mantoani per patria ambedui.'],
#  ['Nacqui sub Iulio, ancor che fosse tardi,',
#   'e vissi a Roma sotto ’l buono Augusto',
#   'al tempo de li dei falsi e bugiardi.'],
#  ['Poeta fui, e cantai di quel giusto',
#   'figliuol d’Anchise che venne di Troia',
#   'poi che il superbo Ilïón fu combusto.'],
#  ['Ma tu perché ritorni a tanta noia?',
#   'perché non sali il dilettoso monte',
#   'ch’è principio e cagion di tutta gioia?»'],
#  ['«Or se’ tu quel Virgilio e quella fonte',
#   'che spandi di parlar sì largo fiume?»,',
#   'rispuos’io lui con vergognosa fronte.'],
#  ['«O de li altri poeti onore e lume,',
#   'vagliami ’l lungo studio e ’l grande amore',
#   'che m’ha fatto cercar lo tuo volume.'],
#  ['Tu se’ lo mio maestro e ’l mio autore,',
#   'tu se’ solo colui da cu’ io tolsi',
#   'lo bello stilo che m’ha fatto onore.'],
#  ['Vedi la bestia per cu’ io mi volsi;',
#   'aiutami da lei, famoso saggio,',
#   'ch’ella mi fa tremar le vene e i polsi».'],
#  ['«A te convien tenere altro viaggio,»',
#   'rispuose, poi che lagrimar mi vide,',
#   '«se vuo’ campar d’esto loco selvaggio;'],
#  ['ché questa bestia, per la qual tu gride,',
#   'non lascia altrui passar per la sua via,',
#   'ma tanto lo ’mpedisce che l’uccide;'],
#  ['e ha natura sì malvagia e ria,',
#   'che mai non empie la bramosa voglia,',
#   'e dopo ’l pasto ha più fame che pria.'],
#  ['Molti son li animali a cui s’ammoglia,',
#   'e più saranno ancora, infin che ’l veltro',
#   'verrà, che la farà morir con doglia.'],
#  ['Questi non ciberà terra né peltro,',
#   'ma sapïenza, amore e virtute,',
#   'e sua nazion sarà tra feltro e feltro.'],
#  ['Di quella umile Italia fia salute',
#   'per cui morì la vergine Cammilla,',
#   'Eurìalo e Turno e Niso di ferute.'],
#  ['Questi la caccerà per ogne villa,',
#   'fin che l’avrà rimessa ne lo ’nferno,',
#   'là onde invidia prima dipartilla.'],
#  ['Ond’io per lo tuo me’ penso e discerno',
#   'che tu mi segui, ed io sarò tua guida,',
#   'e trarrotti di qui per loco etterno,',
#   'ove udirai le disperate strida,',
#   'vedrai li antichi spiriti dolenti,',
#   'ch’a la seconda morte ciascun grida;'],
#  ['e vederai color che son contenti',
#   'nel foco, perché speran di venire',
#   'quando che sia a le beate genti.'],
#  ['A le quai poi se tu vorrai salire,',
#   'anima fia a ciò di me più degna:',
#   'con lei ti lascerò nel mio partire;'],
#  ['ché quello imperador che lassù regna,',
#   'perch’i’ fu’ ribellante a la sua legge,',
#   'non vuol che ’n sua città per me si vegna.'],
#  ['In tutte parti impera e quivi regge;',
#   'quivi è la sua città e l’alto seggio;',
#   'oh felice colui cu’ ivi elegge!»'],
#  ['E io a lui: «Poeta, io ti richeggio',
#   'per quello Dio che tu non conoscesti,',
#   'a ciò ch’io fugga questo male e peggio,',
#   'che tu mi meni là dov’or dicesti,',
#   'sì ch’io veggia la porta di san Pietro',
#   'e color che tu fai cotanto mesti».'],
#  ['Allor si mosse, e io li tenni dietro.']]

# %% [markdown]
# ## Bulding dataset inferno

# %%
def list_to_string(list_s):
    for r in range(0,len(list_s)):
        s=''
        l=[]
        for j in range(0,len(list_s[r])):
            s+=list_s[r][j]
        l.append(s)
        list_s[r]=l
    return list_s

# %%
with open("paraf_inferno.txt","r",encoding="utf-8") as f:
    rows=f.readlines()
    modern_block_texts=dividi_blocchi(rows)

#transform list of string in string
ancient_block_texts=list_to_string(ancient_block_texts)
dataset_dante=pd.DataFrame({"text": ancient_block_texts,"translation":modern_block_texts},columns=["text","translation"])
dataset_dante
# Out:
#                                                  text  \
# 0   [Nel mezzo del cammin di nostra vitami ritrova...
# 1   [Ahi quanto a dir qual era è cosa duraesta sel...
# 2   [Tant’è amara che poco è più morte;ma per trat...
# 3   [Io non so ben ridir com’i’ v’intrai,tant’era ...
# 4   [Ma poi ch’i’ fui al piè d’un colle giunto,là ...
# 5   [Allor fu la paura un poco queta,che nel lago ...
# 6   [E come quei che con lena affannata,uscito fuo...
# 7   [Poi ch’èi posato un poco il corpo lasso,ripre...
# 8   [Ed ecco, quasi al cominciar de l’erta,una lon...
# 9   [Temp’era dal principio del mattino,e ’l sol m...
# 10  [Questi parea che contra me venissecon la test...
# 11  [Ed una lupa, che di tutte bramesembiava carca...
# 12  [E qual è quei che volentieri acquista,e giugn...
# 13  [Mentre ch’i’ rovinava in basso loco,dinanzi a...
# 14  [Quando vidi costui nel gran diserto,«Miserere...
# 15  [Rispuosemi: «Non omo, omo già fui,e li parent...
# 16  [Nacqui sub Iulio, ancor che fosse tardi,e vis...
# 17  [Poeta fui, e cantai di quel giustofigliuol d’...
# 18  [Ma tu perché ritorni a tanta noia?perché non ...
# 19  [«Or se’ tu quel Virgilio e quella fonteche sp...
# 20  [«O de li altri poeti onore e lume,vagliami ’l...
# 21  [Tu se’ lo mio maestro e ’l mio autore,tu se’ ...
# 22  [Vedi la bestia per cu’ io mi volsi;aiutami da...
# 23  [«A te convien tenere altro viaggio,»rispuose,...
# 24  [ché questa bestia, per la qual tu gride,non l...
# 25  [e ha natura sì malvagia e ria,che mai non emp...
# 26  [Molti son li animali a cui s’ammoglia,e più s...
# 27  [Questi non ciberà terra né peltro,ma sapïenza...
# 28  [Di quella umile Italia fia saluteper cui morì...
# 29  [Questi la caccerà per ogne villa,fin che l’av...
# 30  [Ond’io per lo tuo me’ penso e discernoche tu ...
# 31  [e vederai color che son contentinel foco, per...
# 32  [A le quai poi se tu vorrai salire,anima fia a...
# 33  [ché quello imperador che lassù regna,perch’i’...
# 34  [In tutte parti impera e quivi regge;quivi è l...
# 35  [E io a lui: «Poeta, io ti richeggioper quello...
# 36            [Allor si mosse, e io li tenni dietro.]
#
#                                           translation
# 0   [A metà del percorso della vita umana (all'età...
# 1   [Ahimè, è difficile descrivere com'era quella ...
# 2   [È così spaventosa che la morte lo è poco di p...
# 3   [Non sono in grado di spiegare come vi sia ent...
# 4   [Ma dopo che fui arrivato ai piedi di un colle...
# 5   [Allora si placò un poco la paura che avevo av...
# 6   [E come il naufrago che col respiro affannoso,...
# 7   [Dopo che ebbi riposato un poco il corpo stanc...
# 8   [Ed ecco che apparve, quasi all'inizio della s...
# 9   [Erano le prime ore del mattino, e il sole sta...
# 10  [Questi sembrava venire contro di me, con la t...
# 11  [Ed ecco apparire una lupa, che nella sua magr...
# 12  [E come colui che acquista volentieri, e poi a...
# 13  [Mentre io scivolavo a valle, verso la foresta...
# 14  [Quando vidi costui nel luogo deserto, gli gri...
# 15  [Mi rispose: «No, non sono un uomo, lo sono gi...
# 16  [Nacqui sotto il governo di Giulio Cesare, anc...
# 17  [Fui poeta, e cantai di quel giusto figlio di ...
# 18  [Ma tu, perché ritorni al male della foresta? ...
# 19  [«Allora tu sei quel Virgilio e quella sorgent...
# 20  [«O tu che sei luce e guida degli altri poeti,...
# 21  [Tu sei il mio maestro e il mio modello; tu se...
# 22  [Vedi la belva che mi ha fatto voltare; aiutam...
# 23  [«Tu devi compiere un altro viaggio,» mi rispo...
# 24  [Infatti, la belva che ti fa urlare non lascia...
# 25  [E ha un'indole così malvagia e malefica che n...
# 26  [Sono molti gli animali a cui si accoppia, e s...
# 27  [Costui non baderà alle ricchezze materiali, m...
# 28  [Sarà la salvezza di quell'umile Italia, per c...
# 29  [Costui le darà la caccia per ogni città, finc...
# 30  [Perciò io penso e giudico per il tuo bene che...
# 31  [E poi vedrai coloro che sono contenti di subi...
# 32  [E se poi tu vorrai salire a visitare questi u...
# 33  [Infatti, quell'imperatore (Dio) che regna las...
# 34  [Dio ha autorità in tutto l'Universo e in Para...
# 35  [E io gli dissi: «Poeta, in nome di quel Dio c...
# 36       [Allora si mise in cammino, e io lo seguii.]

# %% [markdown]
# ## Build dataset purgatorio

# %%
ancient_block_texts_purgat=list_to_string(ancient_block_texts_purgat)
print(len(ancient_block_texts_purgat))
print(len(modern_block_texts_purgat))
dataset_dante_purgat=pd.DataFrame({"text": ancient_block_texts_purgat,"translation":modern_block_texts_purgat},columns=["text","translation"])
dataset_dante_purgat
# Out:
# 41
# 41
#                                                  text  \
# 0   [Per correr miglior acque alza le veleomai la ...
# 1   [e canterò di quel secondo regnodove l’umano s...
# 2   [Ma qui la morta poesì resurga,o sante Muse, p...
# 3   [Dolce color d’oriental zaffiro,che s’accoglie...
# 4   [Lo bel pianeto che d’amar confortafaceva tutt...
# 5   [I’ mi volsi a man destra, e puosi mentea l’al...
# 6   [Goder pareva ‘l ciel di lor fiammelle:oh sett...
# 7   [Com’io da loro sguardo fui partito,un poco me...
# 8   [vidi presso di me un veglio solo,degno di tan...
# 9   [Lunga la barba e di pel bianco mistaportava, ...
# 10  [Li raggi de le quattro luci santefregiavan sì...
# 11  [«Chi siete voi che contro al cieco fiumefuggi...
# 12  [«Chi v’ha guidati, o che vi fu lucerna,uscend...
# 13  [Son le leggi d’abisso così rotte?o è mutato i...
# 14  [Lo duca mio allor mi diè di piglio,e con paro...
# 15  [Poscia rispuose lui: «Da me non venni:donna s...
# 16  [Ma da ch’è tuo voler che più si spieghidi nos...
# 17  [Questi non vide mai l’ultima sera;ma per la s...
# 18  [Sì com’io dissi, fui mandato ad essoper lui c...
# 19  [Mostrata ho lui tutta la gente ria;e ora inte...
# 20  [Com’io l’ho tratto, saria lungo a dirti;de l’...
# 21  [Or ti piaccia gradir la sua venuta:libertà va...
# 22  [Tu ‘l sai, ché non ti fu per lei amarain Utic...
# 23  [Non son li editti etterni per noi guasti,ché ...
# 24  [Lasciane andar per li tuoi sette regni;grazie...
# 25  [«Marzia piacque tanto a li occhi mieimentre c...
# 26  [Or che di là dal mal fiume dimora,più muover ...
# 27  [Ma se donna del ciel ti muove e regge,come tu...
# 28  [Va dunque, e fa che tu costui ricinghed’un gi...
# 29  [ché non si converria, l’occhio sorprisod’alcu...
# 30  [Questa isoletta intorno ad imo ad imo,là giù ...
# 31  [null’altra pianta che facesse frondao induras...
# 32  [Poscia non sia di qua vostra reddita;lo sol v...
# 33  [Così sparì; e io sù mi levaisanza parlare, e ...
# 34  [El cominciò: «Figliuol, segui i miei passi:vo...
# 35  [L’alba vinceva l’ora mattutinache fuggia inna...
# 36  [Noi andavam per lo solingo pianocom’om che to...
# 37  [Quando noi fummo là ‘ve la rugiadapugna col s...
# 38  [porsi ver’ lui le guance lagrimose:ivi mi fec...
# 39  [Venimmo poi in sul lito diserto,che mai non v...
# 40  [Quivi mi cinse sì com’altrui piacque:oh marav...
#
#                                           translation
# 0   [La navicella del mio ingegno, ormai, alza le ...
# 1   [e io canterò di quel secondo regno (Purgatori...
# 2   [Ma qui la poesia morta risorga, o sante Muse,...
# 3   [Un dolce colore di zaffiro orientale, che si ...
# 4   [Il bel pianeta (Venere) che spinge ad amare i...
# 5   [Io mi rivolsi alla mia destra e osservai il c...
# 6   [Il cielo sembrava godere della loro luce: o e...
# 7   [Non appena ebbi distolto il mio sguardo da es...
# 8   [vidi accanto a me un vecchio solitario, che a...
# 9   [Portava la barba lunga e con peli bianchi e n...
# 10  [La luce delle quattro stelle sante illuminava...
# 11  [Egli ci disse, muovendo quella barba dignitos...
# 12  [Chi vi ha guidati e cosa vi ha indicato la st...
# 13  [Le leggi dell'abisso sono così prive di valor...
# 14  [Allora il mio maestro mi afferrò, e con le pa...
# 15  [Poi gli rispose: «Non sono venuto qui di mia ...
# 16  [Ma poiché il tuo desiderio è che ti spieghiam...
# 17  [Questi non è mai morto, ma per il suo peccato...
# 18  [Come ti ho detto, fui inviato a soccorrerlo; ...
# 19  [Gli ho mostrato tutti i dannati; ora voglio m...
# 20  [Sarebbe lungo spiegarti come l'ho condotto fi...
# 21  [Ora ti prego di accogliere la sua venuta: va ...
# 22  [Tu lo sai bene, poiché per la libertà affront...
# 23  [Gli editti eterni non sono infranti da noi, i...
# 24  [Lasciaci andare per le sette Cornici del Purg...
# 25  [Egli allora disse: «Fin che fui in vita, Marz...
# 26  [Ora che risiede al di là del fiume infernale ...
# 27  [Ma se una donna beata, come dici, muove i tuo...
# 28  [Va' dunque, e fa' in modo di cingere i fianch...
# 29  [infatti non sarebbe opportuno presentarsi di ...
# 30  [Questa isoletta, nelle sue parti più basse, l...
# 31  [nessun'altra pianta che avesse fronde o un tr...
# 32  [Poi il vostro ritorno non sia da questa parte...
# 33  [Così svanì; e io mi alzai senza parlare, e mi...
# 34  [Egli iniziò: «Figliolo, segui i miei passi: t...
# 35  [La luce dell'alba vinceva l'ultima ora della ...
# 36  [Noi andavamo lungo la pianura solitaria, come...
# 37  [Quando fummo là dove la rugiada combatte col ...
# 38  [allora io, che avevo capito cosa volesse fare...
# 39  [Giungemmo poi sul lido deserto, che non vide ...
# 40  [Qui Virgilio mi cinse come Catone gli aveva d...
